# %%
#Q8 (b)	Give an example of a set of preference lists for which there is a switch that would improve the partner of a 
#woman who switched preferences. 
import copy
#women initial preferences
superGroup2 = {
 'A':  ['E', 'D', 'F'],
 'B':  ['D', 'E', 'F'],
 'C':  ['D', 'E', 'F']}
#men initial preferences
superGroup1 = {
 'D':  ['A', 'B', 'C'],
 'E':  ['B', 'A', 'C'],
 'F':  ['A', 'B', 'C']}
 
sg1 = sorted(superGroup1.keys())
sg2 = sorted(superGroup2.keys())
 
 
def check(matchedTeams):
    inverseMatchedTeams = dict((v,k) for k,v in matchedTeams.items())
    for t1, t2 in matchedTeams.items():
        t1likes = superGroup2[t1]
        t1likesbetter = t1likes[:t1likes.index(t2)]
        t2likes = superGroup1[t2]
        t2likesbetter = t2likes[:t2likes.index(t1)]
        for team in t1likesbetter:
            x = inverseMatchedTeams[team]
            y = superGroup1[team]
            if y.index(x) > y.index(t1):
                return False
        for team in t2likesbetter:
            x = matchedTeams[team]
            y = superGroup2[team]
            if y.index(x) > y.index(t2):
                return False
    return True
 
def matchmaker():
    sg1Free = sg1[:]
    matchedTeams  = {}
    superGroup12 = copy.deepcopy(superGroup1)
    superGroup22 = copy.deepcopy(superGroup2)
    while sg1Free:
        team = sg1Free.pop(0)
        sg1List = superGroup12[team]
        team1 = sg1List.pop(0)
        matchedPair = matchedTeams.get(team1)
        if not matchedPair:
            matchedTeams[team1] = team
        else:
            sg2List = superGroup22[team1]
            if sg2List.index(matchedPair) > sg2List.index(team):
                matchedTeams[team1] = team
                print("  %s dumped %s for %s" % (team1, matchedPair, team))
                if superGroup12[matchedPair]:
                    sg1Free.append(matchedPair)
            else:
                if sg1List:
                    sg1Free.append(team)
    return matchedTeams
 
matchedTeams = matchmaker()
 
print('Sorted Groups with initial preferences:')
print('  ' + ',\n  '.join('%s is matched to %s' % team
                          for team in sorted(matchedTeams.items())))
print('Stability check PASSED'
      if check(matchedTeams) else 'Stability check FAILED')
#if woman A lies about her preference and actually prefers F over D then the updated preference would be as below
superGroup2 = {
 'A':  ['E', 'F', 'D'],
 'B':  ['D', 'E', 'F'],
 'C':  ['D', 'E', 'F']}
#Running Gale-shapley algorithm with updated preference
matchedTeams = matchmaker()
print('Sorted Groups with updated preferences:')
print('  ' + ',\n  '.join('%s is matched to %s' % team
                          for team in sorted(matchedTeams.items())))

print('Stability check PASSED'
      if check(matchedTeams) else 'Stability check FAILED')
# Output gives  A-E, B-D, C-F which means woman ended up with her first preference when lied about her initial preferences
# Out:
# Sorted Groups with initial preferences:
#   A is matched to D,
#   B is matched to E,
#   C is matched to F
# Stability check PASSED
#   A dumped D for F
#   B dumped E for D
#   A dumped F for E
# Sorted Groups with updated preferences:
#   A is matched to E,
#   B is matched to D,
#   C is matched to F
# Stability check PASSED

# %%
# 10A.	Find a Gale-Shapley implementation in python on Github and modify it so that the eight Super Group 1 teams will 
#be matched against the eight Super Group 2 teams. You can make up the preference lists for each team. Make sure you cite 
#any code you use or state that you wrote it from scratch if you did. 

import copy
import time
start_time = time.time()
#Creating two supergroups with 8 teams in each supergroup
superGroup1 = {
 'teamSG11':  ['teamSG21', 'teamSG25', 'teamSG23', 'teamSG24', 'teamSG26', 'teamSG22', 'teamSG28', 'teamSG27'],
 'teamSG12':  ['teamSG23', 'teamSG28', 'teamSG21', 'teamSG24', 'teamSG25', 'teamSG26', 'teamSG22',  'teamSG27'],
 'teamSG13':  ['teamSG28', 'teamSG25', 'teamSG21', 'teamSG24', 'teamSG22', 'teamSG26',  'teamSG27', 'teamSG23'],
 'teamSG14':  ['teamSG26', 'teamSG24', 'teamSG27', 'teamSG28', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21'],
 'teamSG15':  ['teamSG24', 'teamSG22', 'teamSG23', 'teamSG26', 'teamSG25', 'teamSG21',  'teamSG28', 'teamSG27'],
 'teamSG16':  ['teamSG22', 'teamSG21', 'teamSG24', 'teamSG27', 'teamSG25',  'teamSG23', 'teamSG28', 'teamSG26'],
 'teamSG17':  ['teamSG27', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21', 'teamSG24', 'teamSG28', 'teamSG26'],
 'teamSG18':  ['teamSG21', 'teamSG25', 'teamSG28', 'teamSG26',  'teamSG23', 'teamSG22', 'teamSG27', 'teamSG24']}
superGroup2 = {
 'teamSG21':  ['teamSG12', 'teamSG16', 'teamSG17', 'teamSG11', 'teamSG14', 'teamSG15', 'teamSG13', 'teamSG18'],
 'teamSG22':  ['teamSG12', 'teamSG11', 'teamSG13', 'teamSG16', 'teamSG17', 'teamSG14', 'teamSG15', 'teamSG18'],
 'teamSG23':  ['teamSG16', 'teamSG12', 'teamSG15', 'teamSG17', 'teamSG18', 'teamSG13', 'teamSG11', 'teamSG14'],
 'teamSG24':  ['teamSG16', 'teamSG13', 'teamSG11', 'teamSG18', 'teamSG17', 'teamSG14', 'teamSG12', 'teamSG15'],
 'teamSG25':  ['teamSG18', 'teamSG16', 'teamSG14', 'teamSG11', 'teamSG17', 'teamSG13', 'teamSG15', 'teamSG12'],
 'teamSG26':  ['teamSG12', 'teamSG11', 'teamSG15', 'teamSG14', 'teamSG16', 'teamSG17', 'teamSG13', 'teamSG18'],
 'teamSG27':  ['teamSG17', 'teamSG18', 'teamSG16', 'teamSG12', 'teamSG11', 'teamSG13', 'teamSG15', 'teamSG14'],
 'teamSG28':  ['teamSG17', 'teamSG12', 'teamSG11', 'teamSG14', 'teamSG18', 'teamSG15', 'teamSG13', 'teamSG16']}
 
sg1 = sorted(superGroup1.keys())
sg2 = sorted(superGroup2.keys())
 
#checking stability of algorithm executed by checking if a team prefers any other team over the matched team
def check(matchedTeams):
    inverseMatchedTeams = dict((v,k) for k,v in matchedTeams.items())
    for t1, t2 in matchedTeams.items():
        t1likes = superGroup2[t1]
        t1likesbetter = t1likes[:t1likes.index(t2)]
        t2likes = superGroup1[t2]
        t2likesbetter = t2likes[:t2likes.index(t1)]
        for team in t1likesbetter:
            x = inverseMatchedTeams[team]
            y = superGroup1[team]
            if y.index(x) > y.index(t1):
                print("%s and %s like each other better than "
                      "their present partners: %s and %s, respectively"
                      % (t1, team, t2, x))
                return False
        for team in t2likesbetter:
            x = matchedTeams[team]
            y = superGroup2[team]
            if y.index(x) > y.index(t2):
                print("%s and %s like each other better than "
                      "their present partners: %s and %s, respectively"
                      % (t2, team, t1, x))
                return False
    return True
#matching teams based on their preferences
def matchmaker():
    sg1Free = sg1[:]
    matchedTeams  = {}
    superGroup12 = copy.deepcopy(superGroup1)
    superGroup22 = copy.deepcopy(superGroup2)
    while sg1Free:
        team = sg1Free.pop(0)
        sg1List = superGroup12[team]
        team1 = sg1List.pop(0)
        matchedPair = matchedTeams.get(team1)
        if not matchedPair:
            # team1's free
            matchedTeams[team1] = team
            print("  %s and %s" % (team, team1))
        else:
            sg2List = superGroup22[team1]
            if sg2List.index(matchedPair) > sg2List.index(team):
                matchedTeams[team1] = team
                print("  %s dumped %s for %s" % (team1, matchedPair, team))
                if superGroup12[matchedPair]:
                    sg1Free.append(matchedPair)
            else:
                if sg1List:
                    sg1Free.append(team)
    return matchedTeams
 
print('\nTournament pairups:')
matchedTeams = matchmaker()
 
print('Sorted Team matches:')
print('  ' + ',\n  '.join('%s is matched to %s' % team
                          for team in sorted(matchedTeams.items())))
print()
print('Stability check PASSED'
      if check(matchedTeams) else 'Stability check FAILED')
print("Execution time for 16 teams", (time.time() - start_time))
# Out:
# Tournament pairups:
#   teamSG11 and teamSG21
#   teamSG12 and teamSG23
#   teamSG13 and teamSG28
#   teamSG14 and teamSG26
#   teamSG15 and teamSG24
#   teamSG16 and teamSG22
#   teamSG17 and teamSG27
#   teamSG18 and teamSG25
# Sorted Team matches:
#   teamSG21 is matched to teamSG11,
#   teamSG22 is matched to teamSG16,
#   teamSG23 is matched to teamSG12,
#   teamSG24 is matched to teamSG15,
#   teamSG25 is matched to teamSG18,
#   teamSG26 is matched to teamSG14,
#   teamSG27 is matched to teamSG17,
#   teamSG28 is matched to teamSG13
#
# Stability check PASSED
# Execution time for 16 teams 0.03200817108154297

# %%
#10B.	Use a loop to shuffle the preference lists for each team 1000 times.  Calculate the percentage of stable playoff 
#matches.  See the function random.shuffle(x[, random])   
import copy
import random
superGroup1 = {
 'teamSG11':  ['teamSG21', 'teamSG25', 'teamSG23', 'teamSG24', 'teamSG26', 'teamSG22', 'teamSG28', 'teamSG27'],
 'teamSG12':  ['teamSG23', 'teamSG28', 'teamSG21', 'teamSG24', 'teamSG25', 'teamSG26', 'teamSG22',  'teamSG27'],
 'teamSG13':  ['teamSG28', 'teamSG25', 'teamSG21', 'teamSG24', 'teamSG22', 'teamSG26',  'teamSG27', 'teamSG23'],
 'teamSG14':  ['teamSG26', 'teamSG24', 'teamSG27', 'teamSG28', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21'],
 'teamSG15':  ['teamSG24', 'teamSG22', 'teamSG23', 'teamSG26', 'teamSG25', 'teamSG21',  'teamSG28', 'teamSG27'],
 'teamSG16':  ['teamSG22', 'teamSG21', 'teamSG24', 'teamSG27', 'teamSG25',  'teamSG23', 'teamSG28', 'teamSG26'],
 'teamSG17':  ['teamSG27', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21', 'teamSG24', 'teamSG28', 'teamSG26'],
 'teamSG18':  ['teamSG21', 'teamSG25', 'teamSG28', 'teamSG26',  'teamSG23', 'teamSG22', 'teamSG27', 'teamSG24']}
superGroup2 = {
 'teamSG21':  ['teamSG12', 'teamSG16', 'teamSG17', 'teamSG11', 'teamSG14', 'teamSG15', 'teamSG13', 'teamSG18'],
 'teamSG22':  ['teamSG12', 'teamSG11', 'teamSG13', 'teamSG16', 'teamSG17', 'teamSG14', 'teamSG15', 'teamSG18'],
 'teamSG23':  ['teamSG16', 'teamSG12', 'teamSG15', 'teamSG17', 'teamSG18', 'teamSG13', 'teamSG11', 'teamSG14'],
 'teamSG24':  ['teamSG16', 'teamSG13', 'teamSG11', 'teamSG18', 'teamSG17', 'teamSG14', 'teamSG12', 'teamSG15'],
 'teamSG25':  ['teamSG18', 'teamSG16', 'teamSG14', 'teamSG11', 'teamSG17', 'teamSG13', 'teamSG15', 'teamSG12'],
 'teamSG26':  ['teamSG12', 'teamSG11', 'teamSG15', 'teamSG14', 'teamSG16', 'teamSG17', 'teamSG13', 'teamSG18'],
 'teamSG27':  ['teamSG17', 'teamSG18', 'teamSG16', 'teamSG12', 'teamSG11', 'teamSG13', 'teamSG15', 'teamSG14'],
 'teamSG28':  ['teamSG17', 'teamSG12', 'teamSG11', 'teamSG14', 'teamSG18', 'teamSG15', 'teamSG13', 'teamSG16']}
 
sg1 = sorted(superGroup1.keys())
sg2 = sorted(superGroup2.keys())
 
#checking stability of algorithm executed by checking if a team prefers any other team over the matched team
def check(matchedTeams):
    inverseMatchedTeams = dict((v,k) for k,v in matchedTeams.items())
    for t1, t2 in matchedTeams.items():
        t1likes = superGroup2[t1]
        t1likesbetter = t1likes[:t1likes.index(t2)]
        t2likes = superGroup1[t2]
        t2likesbetter = t2likes[:t2likes.index(t1)]
        for team in t1likesbetter:
            x = inverseMatchedTeams[team]
            y = superGroup1[team]
            if y.index(x) > y.index(t1):
                return False
        for team in t2likesbetter:
            x = matchedTeams[team]
            y = superGroup2[team]
            if y.index(x) > y.index(t2):
                return False
    return True
#matching teams based on their preferences
def matchmaker():
    sg1Free = sg1[:]
    matchedTeams  = {}
    superGroup12 = copy.deepcopy(superGroup1)
    superGroup22 = copy.deepcopy(superGroup2)
    while sg1Free:
        team = sg1Free.pop(0)
        sg1List = superGroup12[team]
        team1 = sg1List.pop(0)
        matchedPair = matchedTeams.get(team1)
        if not matchedPair:
            matchedTeams[team1] = team
        else:
            sg2List = superGroup22[team1]
            if sg2List.index(matchedPair) > sg2List.index(team):
                matchedTeams[team1] = team
                if superGroup12[matchedPair]:
                    sg1Free.append(matchedPair)
            else:
                if sg1List:
                    sg1Free.append(team)
    return matchedTeams
#initialised count to 0, shuffling SuperGroup1 and SuperGroup2 1000 times and calling matchmaker() and check() to 
#test stable matching in all 1000 cases. Incremented count by 1 when stable matching is done and calculated percentage based
#on count value
count = 0;
for i in range(1000):
        for j in superGroup1.values():
            random.shuffle(j)
        for j in superGroup2.values():
            random.shuffle(j)
        matchedTeams = matchmaker()
        if(check(matchedTeams)):
            count += 1
print("The percentage of stable playoff matches is {}%".format(count//1000 * 100))
# Out:
# The percentage of stable playoff matches is 100%

# %%
#10C.	Randomly assume certain teams win and lose each round and eliminate the losers from the preference lists for each team. 
#Can the Gale-Shapley matching algorithm be applied over and over in each round (16 teams, 8 teams, 4 teams, 2 teams) to 
#create stable matches? You can answer this with code or rhetoric. 

import copy
 
superGroup1 = {
 'teamSG11':  ['teamSG21', 'teamSG25', 'teamSG23', 'teamSG24', 'teamSG26', 'teamSG22', 'teamSG28', 'teamSG27'],
 'teamSG12':  ['teamSG23', 'teamSG28', 'teamSG21', 'teamSG24', 'teamSG25', 'teamSG26', 'teamSG22',  'teamSG27'],
 'teamSG13':  ['teamSG28', 'teamSG25', 'teamSG21', 'teamSG24', 'teamSG22', 'teamSG26',  'teamSG27', 'teamSG23'],
 'teamSG14':  ['teamSG26', 'teamSG24', 'teamSG27', 'teamSG28', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21'],
 'teamSG15':  ['teamSG24', 'teamSG22', 'teamSG23', 'teamSG26', 'teamSG25', 'teamSG21',  'teamSG28', 'teamSG27'],
 'teamSG16':  ['teamSG22', 'teamSG21', 'teamSG24', 'teamSG27', 'teamSG25',  'teamSG23', 'teamSG28', 'teamSG26'],
 'teamSG17':  ['teamSG27', 'teamSG25', 'teamSG22', 'teamSG23', 'teamSG21', 'teamSG24', 'teamSG28', 'teamSG26'],
 'teamSG18':  ['teamSG21', 'teamSG25', 'teamSG28', 'teamSG26',  'teamSG23', 'teamSG22', 'teamSG27', 'teamSG24']}
superGroup2 = {
 'teamSG21':  ['teamSG12', 'teamSG16', 'teamSG17', 'teamSG11', 'teamSG14', 'teamSG15', 'teamSG13', 'teamSG18'],
 'teamSG22':  ['teamSG12', 'teamSG11', 'teamSG13', 'teamSG16', 'teamSG17', 'teamSG14', 'teamSG15', 'teamSG18'],
 'teamSG23':  ['teamSG16', 'teamSG12', 'teamSG15', 'teamSG17', 'teamSG18', 'teamSG13', 'teamSG11', 'teamSG14'],
 'teamSG24':  ['teamSG16', 'teamSG13', 'teamSG11', 'teamSG18', 'teamSG17', 'teamSG14', 'teamSG12', 'teamSG15'],
 'teamSG25':  ['teamSG18', 'teamSG16', 'teamSG14', 'teamSG11', 'teamSG17', 'teamSG13', 'teamSG15', 'teamSG12'],
 'teamSG26':  ['teamSG12', 'teamSG11', 'teamSG15', 'teamSG14', 'teamSG16', 'teamSG17', 'teamSG13', 'teamSG18'],
 'teamSG27':  ['teamSG17', 'teamSG18', 'teamSG16', 'teamSG12', 'teamSG11', 'teamSG13', 'teamSG15', 'teamSG14'],
 'teamSG28':  ['teamSG17', 'teamSG12', 'teamSG11', 'teamSG14', 'teamSG18', 'teamSG15', 'teamSG13', 'teamSG16']}
#checking stability of algorithm executed by checking if a team prefers any other team over the matched team
def check(matchedTeams):
    inverseMatchedTeams = dict((v,k) for k,v in matchedTeams.items())
    for t1, t2 in matchedTeams.items():
        t1likes = superGroup2[t1]
        t1likesbetter = t1likes[:t1likes.index(t2)]
        t2likes = superGroup1[t2]
        t2likesbetter = t2likes[:t2likes.index(t1)]
        for team in t1likesbetter:
            x = inverseMatchedTeams[team]
            y = superGroup1[team]
            if y.index(x) > y.index(t1):
                return False
        for team in t2likesbetter:
            x = matchedTeams[team]
            y = superGroup2[team]
            if y.index(x) > y.index(t2):
                return False
    return True
#matching teams based on their preferences
def matchmaker():
    sg1 = sorted(superGroup1.keys())
    sg2 = sorted(superGroup2.keys())
    sg1Free = sg1[:]
    matchedTeams  = {}
    superGroup12 = copy.deepcopy(superGroup1)
    superGroup22 = copy.deepcopy(superGroup2)
    while sg1Free:
        team = sg1Free.pop(0)
        sg1List = superGroup12[team]
        team1 = sg1List.pop(0)
        matchedPair = matchedTeams.get(team1)
        if not matchedPair:
            matchedTeams[team1] = team
        else:
            sg2List = superGroup22[team1]
            if sg2List.index(matchedPair) > sg2List.index(team):
                matchedTeams[team1] = team
                if superGroup12[matchedPair]:
                    sg1Free.append(matchedPair)
            else:
                if sg1List:
                    sg1Free.append(team)
    return matchedTeams
#takes team to be removed and the supergroup in which it is present as a input
#removes team key from supergroup and update preferences of other teams in superGroup2
def removeTeams(team, superGroup):
    if(superGroup == 'superGroup1'):
        superGroup1.pop(team)
        for i in superGroup2:
            superGroup2[i].remove(team)
    else:
        superGroup2.pop(team)
        for i in superGroup1:
            superGroup1[i].remove(team)
#calls matchmaker(), check() -> matches teams and checks if matched pairs are stable
def tournamentPairsCheck():
    matchedTeams = matchmaker()
    print('Sorted Team matches:')
    print('  ' + ',\n  '.join('%s is matched to %s' % team
                          for team in sorted(matchedTeams.items())))
    print('Stability check PASSED'
          if check(matchedTeams) else 'Engagement stability check FAILED')
tournamentPairsCheck()
#Loop to generate team names and call removeTeams -> Removes 4 teams from each supergroup first and then 2 teams from each
#and then 1 from each supergroup -> After removing, matches pair and checks stability by calling tournamentPairsCheck
i = 4 
while i >= 1:
    for j in range(i):
        team = 'teamSG1' + str(j+i+1)
        removeTeams(team, 'superGroup1')
        team2 = 'teamSG2'+ str(j+i+1)
        removeTeams(team2, 'superGroup2')
    tournamentPairsCheck()
    i = i//2
# Out:
# Sorted Team matches:
#   teamSG21 is matched to teamSG11,
#   teamSG22 is matched to teamSG16,
#   teamSG23 is matched to teamSG12,
#   teamSG24 is matched to teamSG15,
#   teamSG25 is matched to teamSG18,
#   teamSG26 is matched to teamSG14,
#   teamSG27 is matched to teamSG17,
#   teamSG28 is matched to teamSG13
# Stability check PASSED
# Sorted Team matches:
#   teamSG21 is matched to teamSG11,
#   teamSG22 is matched to teamSG14,
#   teamSG23 is matched to teamSG12,
#   teamSG24 is matched to teamSG13
# Stability check PASSED
# Sorted Team matches:
#   teamSG21 is matched to teamSG12,
#   teamSG22 is matched to teamSG11
# Stability check PASSED
# Sorted Team matches:
#   teamSG21 is matched to teamSG11
# Stability check PASSED

# %%
#10E.	Double the size of the lists in problem A several times (you can make up team names like team1, team2, etc.) 
#and measure the amount of time it takes to create stable matches.  How fast does the execution time grow in relation to the
#size of the lists? 
import copy
import time
start_time = time.time()

superGroup1 = {
 'teamSG11':  ['teamSG22','teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teama21','teama22','teama23','teama24','teama25','teama26','teama27','teama28'],
 'teamSG12':  ['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama21','teama25','teama26','teama27','teama28'],
 'teamSG13':  ['teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teamSG23','teama21','teama22','teama23','teama24','teama27','teama26','teama25','teama28'],
 'teamSG14':  ['teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teamSG23','teamSG24','teama21','teama24','teama23','teama22','teama25','teama26','teama28','teama27'],
 'teamSG15':  ['teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teamSG23','teamSG24','teamSG25','teama28','teama23','teama22','teama24','teama25','teama26','teama27','teama21'],
 'teamSG16':  ['teamSG27','teamSG28','teamSG21','teamSG22','teamSG23','teamSG24','teamSG25','teamSG26','teama21','teama22','teama23','teama24','teama25','teama26','teama27','teama28'],
 'teamSG17':  ['teamSG28','teamSG21','teamSG22','teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teama21','teama24','teama28','teama22','teama25','teama26','teama27','teama23'],
 'teamSG18':  ['teamSG21','teamSG22','teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teama21','teama22','teama23','teama24','teama25','teama28','teama26','teama27'],
 'teama11': ['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama21','teama24','teama25','teama28','teama27','teama26'],
 'teama12': ['teamSG21','teamSG22','teamSG25','teamSG26','teamSG27','teamSG28','teamSG24','teamSG23','teama22','teama23','teama24','teama25','teama21','teama26','teama27','teama28'],
 'teama13':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama21','teama25','teama26','teama27','teama28'],
 'teama14':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama21','teama23','teama24','teama22','teama25','teama26','teama27','teama28'],
 'teama15':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama25','teama21','teama26','teama27','teama28'],
 'teama16':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama21','teama25','teama26','teama27','teama28'],
 'teama17':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama21','teama25','teama26','teama27','teama28'],
 'teama18':['teamSG23','teamSG24','teamSG25','teamSG26','teamSG27','teamSG28','teamSG21','teamSG22','teama22','teama23','teama24','teama21','teama28','teama26','teama27','teama25']}



superGroup2 = {
 'teamSG21':  ['teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teama11','teama12','teama13','teama14','teama15','teama16','teama17','teama18'],
 'teamSG22':  ['teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teama12','teama11','teama14','teama13','teama15','teama16','teama17','teama18'],
 'teamSG23': ['teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teamSG12','teama11','teama12','teama13','teama14','teama15','teama16','teama18','teama17'],
 'teamSG24':  ['teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teamSG12','teamSG13','teama11','teama12','teama13','teama14','teama16','teama15','teama17','teama18'],
 'teamSG25':  ['teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teama11','teama12','teama14','teama13','teama15','teama16','teama17','teama18'],
 'teamSG26':  ['teamSG16','teamSG17','teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teama18','teama12','teama13','teama14','teama15','teama16','teama11','teama17'],
 'teamSG27':  ['teamSG17','teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teama15','teama12','teama13','teama11','teama14','teama16','teama17','teama18'],
 'teamSG28': ['teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teama15','teama12','teama13','teama14','teama11','teama17','teama18','teama16'],
 'teama21':['teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teama15','teama12','teama13','teama14','teama11','teama17','teama18','teama16'],
 'teama22':['teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teama11','teama12','teama13','teama14','teama15','teama16','teama17','teama18'],
 'teama23':['teamSG12','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teamSG13','teama11','teama12','teama13','teama14','teama15','teama16','teama18','teama17'],
 'teama24':['teamSG17','teamSG18','teamSG11','teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teama15','teama12','teama13','teama11','teama14','teama16','teama17','teama18'],
 'teama25':['teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG18','teamSG17','teamSG11','teama12','teama11','teama14','teama13','teama15','teama16','teama17','teama18'],
 'teama26':['teamSG11','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG12','teama12','teama11','teama14','teama13','teama15','teama16','teama17','teama18'],
 'teama27':['teamSG12','teamSG13','teamSG14','teamSG15','teamSG17','teamSG16','teamSG18','teamSG11','teama12','teama11','teama14','teama13','teama15','teama16','teama17','teama18'],
 'teama28': ['teamSG12','teamSG13','teamSG14','teamSG15','teamSG16','teamSG17','teamSG18','teamSG11','teama12','teama11','teama14','teama13','teama15','teama16','teama17','teama18']}

sg1 = sorted(superGroup1.keys())
sg2 = sorted(superGroup2.keys())
 
def check(matchedTeams):
    inverseMatchedTeams = dict((v,k) for k,v in matchedTeams.items())
    for t1, t2 in matchedTeams.items():
        t1likes = superGroup2[t1]
        t1likesbetter = t1likes[:t1likes.index(t2)]
        t2likes = superGroup1[t2]
        t2likesbetter = t2likes[:t2likes.index(t1)]
        for team in t1likesbetter:
            x = inverseMatchedTeams[team]
            y = superGroup1[team]
            if y.index(x) > y.index(t1):
                print("%s and %s like each other better than "
                      "their present partners: %s and %s, respectively"
                      % (t1, team, t2, x))
                return False
        for team in t2likesbetter:
            x = matchedTeams[team]
            y = superGroup2[team]
            if y.index(x) > y.index(t2):
                print("%s and %s like each other better than "
                      "their present partners: %s and %s, respectively"
                      % (t2, team, t1, x))
                return False
    return True
 
def matchmaker():
    sg1Free = sg1[:]
    matchedTeams  = {}
    superGroup12 = copy.deepcopy(superGroup1)
    superGroup22 = copy.deepcopy(superGroup2)
    while sg1Free:
        team = sg1Free.pop(0)
        sg1List = superGroup12[team]
        team1 = sg1List.pop(0)
        matchedPair = matchedTeams.get(team1)
        if not matchedPair:
            matchedTeams[team1] = team
            print("  %s and %s" % (team, team1))
        else:
            sg2List = superGroup22[team1]
            if sg2List.index(matchedPair) > sg2List.index(team):
                matchedTeams[team1] = team
                print("  %s dumped %s for %s" % (team1, matchedPair, team))
                if superGroup12[matchedPair]:
                    sg1Free.append(matchedPair)
            else:
                if sg1List:
                    sg1Free.append(team)
    return matchedTeams
 
 
print('\nTournament pairups:')
matchedTeams = matchmaker()
 
print('\Sorted Team matches:')
print('  ' + ',\n  '.join('%s is matched to %s' % team
                          for team in sorted(matchedTeams.items())))
print()
print('Stability check PASSED'
      if check(matchedTeams) else 'Stability check FAILED')
print("Execution time for 32 teams", (time.time() - start_time))
# Out:
# Tournament pairups:
#   teamSG11 and teamSG22
#   teamSG12 and teamSG23
#   teamSG13 and teamSG24
#   teamSG14 and teamSG25
#   teamSG15 and teamSG26
#   teamSG16 and teamSG27
#   teamSG17 and teamSG28
#   teamSG18 and teamSG21
#   teama11 and teama22
#   teama14 and teama21
#   teama12 and teama23
#   teama13 and teama24
#   teama24 dumped teama13 for teama15
#   teama21 dumped teama14 for teama13
#   teama16 and teama25
#   teama18 and teama28
#   teama17 and teama26
#   teama25 dumped teama16 for teama14
#   teama26 dumped teama17 for teama16
#   teama17 and teama27
# \Sorted Team matches:
#   teamSG21 is matched to teamSG18,
#   teamSG22 is matched to teamSG11,
#   teamSG23 is matched to teamSG12,
#   teamSG24 is matched to teamSG13,
#   teamSG25 is matched to teamSG14,
#   teamSG26 is matched to teamSG15,
#   teamSG27 is matched to teamSG16,
#   teamSG28 is matched to teamSG17,
#   teama21 is matched to teama13,
#   teama22 is matched to teama11,
# ...
